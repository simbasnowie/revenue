# %%
import pyspark.sql.functions as F
from pyspark.sql.types import StructType, StructField
from pyspark.sql.types import DoubleType, IntegerType, StringType, FloatType, DateType

#Ingestion Process
def IngestCSV(path):
    schema = StructType([
        StructField("FirstName", StringType()),
        StructField("LastName", StringType()),
        StructField("Company", StringType()),
        StructField("BirthDate", IntegerType()),
        StructField("Salary", FloatType()),
        StructField("Address", StringType()),
        StructField("Suburb", StringType()),
        StructField("State", StringType()),
        StructField("Post", IntegerType()),
        StructField("Phone", IntegerType()),
        StructField("Mobile", IntegerType()),
        StructField("Email", StringType()),
    ])    
    df = (spark.read
    .format("csv")
    .option("mode", "PERMISSIVE")
    .schema(schema)
    .load(path, format="csv", sep="|", mode="PERMISSIVE", header="false")
    )
    return df

# %%
#Transform Process
def Transform(df):
    df = df.withColumn("FullName", F.concat_ws(" ", F.trim(F.col("FirstName")), F.trim(F.col("LastName"))))
    df = df.withColumn('SalaryBucket',  F.when(F.col('Salary') < 50000, F.lit("A"))
                                         .when((F.col('Salary') >= 50000) & (F.col('Salary') <= 100000), F.lit("B"))
                                         .otherwise(F.lit("C")))
                       
    df = df.withColumn('Salary', F.concat(F.lit("$"), F.format_number('Salary', 4).cast("string")))
    df = df.withColumn('BirthDateTemp', F.from_unixtime('BirthDate').cast(DateType()))
    df = df.withColumn('BirthDate', F.date_format(F.from_unixtime('BirthDate').cast(DateType()), 'dd/MM/yyyy'))
    df = df.withColumn('age', (F.months_between(F.current_date(), F.col('BirthDateTemp')) / 12).cast('int'))
    df = df.drop("FirstName", "LastName", "BirthDateTemp")
    df.createOrReplaceTempView("member_data")       
    return df

# %%
#Load Process - Extract to JSON 
def Load(df):
    results = df.toPandas().to_json(orient='records')
    print(results)

# %%
#ETL Pipeline Run
Load(Transform(IngestCSV("abfss://test.dfs.core.windows.net/member-data.csv")))
# Out:
# [{"Company":"Brandt, Jonathan F Esq","BirthDate":"05\/07\/1970","Salary":"$330,949.2188","Address":"171 E 24th St","Suburb":"Leith","State":"TAS","Post":7315,"Phone":381749123,"Mobile":458665290,"Email":"rebbecca.didio@didio.com.au","FullName":"Rebbecca Didio","SalaryBucket":"C","age":54.0},{"Company":"Landrum Temporary Services","BirthDate":"17\/07\/1970","Salary":"$309,558.5312","Address":"22222 Acoma St","Suburb":"Proston","State":"QLD","Post":4613,"Phone":799973366,"Mobile":497622620,"Email":"stevie.hallo@hotmail.com","FullName":"Stevie Hallo","SalaryBucket":"C","age":54.0},{"Company":"Inabinet, Macre Esq","BirthDate":"24\/01\/1970","Salary":"$539,508.3750","Address":"534 Schoenborn St #51","Suburb":"Hamel","State":"WA","Post":6215,"Phone":855589019,"Mobile":427885282,"Email":"mariko_stayer@hotmail.com","FullName":"Mariko Stayer","SalaryBucket":"C","age":54.0},{"Company":"Morris Downing & Sherred","BirthDate":"12\/06\/1970","Salary":"$293,515.5000","Address":"69206 Jackson Ave","Suburb":"Talmalmo","State":"NSW","Post":2640,"Phone":260444682,"Mobile":443795912,"Email":"gerardo_woodka@hotmail.com","FullName":"Gerardo Woodka","SalaryBucket":"C","age":54.0},{"Company":"Buelt, David L Esq","BirthDate":"21\/08\/1970","Salary":"$395,121.2500","Address":"808 Glen Cove Ave","Suburb":"Lane Cove","State":"NSW","Post":1595,"Phone":214556085,"Mobile":453666885,"Email":"mayra.bena@gmail.com","FullName":"Mayra Bena","SalaryBucket":"C","age":54.0},{"Company":"Artesian Ice & Cold Storage Co","BirthDate":"14\/12\/1970","Salary":"$573,376.9375","Address":"373 Lafayette St","Suburb":"Cartmeticup","State":"WA","Post":6316,"Phone":878681355,"Mobile":451966921,"Email":"idella@hotmail.com","FullName":"Idella Scotland","SalaryBucket":"C","age":53.0},{"Company":"Midway Hotel","BirthDate":"05\/07\/1970","Salary":"$896,019.7500","Address":"87 Sylvan Ave","Suburb":"Nyamup","State":"WA","Post":6258,"Phone":865228931,"Mobile":427991688,"Email":"sklar@hotmail.com","FullName":"Sherill Klar","SalaryBucket":"C","age":54.0},{"Company":"Selsor, Robert J Esq","BirthDate":"13\/01\/1970","Salary":"$863,933.7500","Address":"60562 Ky Rt 321","Suburb":"Bendick Murrell","State":"NSW","Post":2803,"Phone":252269402,"Mobile":415961606,"Email":"ena_desjardiws@desjardiws.com.au","FullName":"Ena Desjardiws","SalaryBucket":"C","age":54.0},{"Company":"Vincent J Petti & Co","BirthDate":"20\/05\/1970","Salary":"$756,980.3125","Address":"70 S 18th Pl","Suburb":"Purrawunda","State":"QLD","Post":4356,"Phone":731849989,"Mobile":411732965,"Email":"vince_siena@yahoo.com","FullName":"Vince Siena","SalaryBucket":"C","age":54.0},{"Company":"Prentiss, Paul F Esq ","BirthDate":"03\/12\/1970","Salary":"$382,643.3438","Address":"8839 Ventura Blvd","Suburb":"Blanchetown","State":"SA","Post":5357,"Phone":868904661,"Mobile":461862457,"Email":"tjarding@hotmail.com","FullName":"Theron Jarding","SalaryBucket":"C","age":53.0},{"Company":"Public Works Department","BirthDate":"28\/02\/1970","Salary":"$662,504.8125","Address":"3684 N Wacker Dr","Suburb":"Rockside","State":"QLD","Post":4343,"Phone":781353271,"Mobile":478867289,"Email":"amira.chudej@chudej.net.au","FullName":"Amira Chudej","SalaryBucket":"C","age":54.0},{"Company":"Prudential Lighting Corp","BirthDate":"24\/01\/1970","Salary":"$377,295.6875","Address":"68828 S 32nd St #6","Suburb":"Rosegarland","State":"TAS","Post":7140,"Phone":311746817,"Mobile":494982617,"Email":"marica.tarbor@hotmail.com","FullName":"Marica Tarbor","SalaryBucket":"C","age":54.0},{"Company":"Wood, J Scott Esq","BirthDate":"16\/04\/1970","Salary":"$872,846.5000","Address":"43157 Cypress St","Suburb":"Ringwood","State":"QLD","Post":4343,"Phone":779776039,"Mobile":441255802,"Email":"shawna.albrough@albrough.com.au","FullName":"Shawna Albrough","SalaryBucket":"C","age":54.0},{"Company":"Swanson Peterson Fnrl Home Inc","BirthDate":"14\/12\/1970","Salary":"$106,347.0234","Address":"6 S Hanover Ave","Suburb":"Maylands","State":"WA","Post":6931,"Phone":883448929,"Mobile":4 ...
#
# *** WARNING: max output size exceeded, skipping output. ***
#
# s","SalaryBucket":"C","age":54.0},{"Company":"Georgia Business Machines","BirthDate":"01\/06\/1970","Salary":"$732,024.5000","Address":"722 E Liberty St","Suburb":"Bygalorie","State":"NSW","Post":2669,"Phone":246495341,"Mobile":459496184,"Email":"anna.ovit@hotmail.com","FullName":"Anna Ovit","SalaryBucket":"C","age":54.0},{"Company":"Leo, Frank M","BirthDate":"12\/06\/1970","Salary":"$560,899.0625","Address":"9 Gunnison St","Suburb":"Oakhurst","State":"NSW","Post":2761,"Phone":257708546,"Mobile":410116435,"Email":"shawnta@woodhams.com.au","FullName":"Shawnta Woodhams","SalaryBucket":"C","age":54.0},{"Company":"S E M A","BirthDate":"17\/10\/1970","Salary":"$95,651.6797","Address":"2902 Edison Dr #278","Suburb":"Mandurah East","State":"WA","Post":6210,"Phone":893787021,"Mobile":424568217,"Email":"ettie@yahoo.com","FullName":"Ettie Luckenbach","SalaryBucket":"B","age":53.0},{"Company":"Arthur Andersen & Co","BirthDate":"21\/11\/1970","Salary":"$174,084.1875","Address":"72 N Buckeye Ave","Suburb":"Daisy Hill","State":"VIC","Post":3465,"Phone":325748915,"Mobile":415341310,"Email":"cleveston@gmail.com","FullName":"Chara Leveston","SalaryBucket":"C","age":53.0},{"Company":"Triangle Engineering Inc","BirthDate":"01\/09\/1970","Salary":"$240,038.7969","Address":"41 E Jackson St","Suburb":"Willetton","State":"WA","Post":6155,"Phone":827043706,"Mobile":476605889,"Email":"lhuntsberger@huntsberger.net.au","FullName":"Lauran Huntsberger","SalaryBucket":"C","age":54.0},{"Company":"Schmidt, Charles E Jr","BirthDate":"13\/01\/1970","Salary":"$186,562.0938","Address":"684 William St","Suburb":"Tarnagulla","State":"VIC","Post":3551,"Phone":332334255,"Mobile":467468894,"Email":"pansy_todesco@gmail.com","FullName":"Pansy Todesco","SalaryBucket":"C","age":54.0},{"Company":"Emess Professional Svces","BirthDate":"03\/04\/1970","Salary":"$714,198.9375","Address":"185 W Guadalupe Rd","Suburb":"Steels Creek","State":"VIC","Post":3775,"Phone":374166750,"Mobile":436793916,"Email":"georgeanna@silverstone.net.au","FullName":"Georgeanna Silverstone","SalaryBucket":"C","age":54.0},{"Company":"White, Mark A Cpa","BirthDate":"11\/03\/1970","Salary":"$348,774.7812","Address":"18514 E 4th St #8","Suburb":"Broken Head","State":"NSW","Post":2481,"Phone":244185927,"Mobile":467331796,"Email":"jesus.liversedge@hotmail.com","FullName":"Jesus Liversedge","SalaryBucket":"C","age":54.0},{"Company":"Vicon Corporation","BirthDate":"03\/12\/1970","Salary":"$651,809.4375","Address":"28 Standiford Ave #6","Suburb":"Bundaberg West","State":"QLD","Post":4670,"Phone":760735039,"Mobile":481690589,"Email":"jamey.tetter@gmail.com","FullName":"Jamey Tetter","SalaryBucket":"C","age":53.0},{"Company":"Turl Engineering Works","BirthDate":"17\/07\/1970","Salary":"$79,608.6641","Address":"33108 S Yosemite Ct","Suburb":"Port Melbourne","State":"VIC","Post":3207,"Phone":312488221,"Mobile":491832907,"Email":"alberta_motter@hotmail.com","FullName":"Alberta Motter","SalaryBucket":"B","age":54.0},{"Company":"Deep Creek Pharmacy","BirthDate":"06\/10\/1970","Salary":"$612,593.1875","Address":"73778 Battery St","Suburb":"Happy Valley","State":"SA","Post":5159,"Phone":833055436,"Mobile":457126909,"Email":"ronald.grube@yahoo.com","FullName":"Ronald Grube","SalaryBucket":"C","age":54.0},{"Company":"Mister Bagel","BirthDate":"12\/09\/1970","Salary":"$516,335.1250","Address":"351 Crooks Rd","Suburb":"Benambra","State":"VIC","Post":3900,"Phone":336952399,"Mobile":432182830,"Email":"tamala_hickie@yahoo.com","FullName":"Tamala Hickie","SalaryBucket":"C","age":54.0},{"Company":"Howard Winig Realty Assocs Inc","BirthDate":"11\/03\/1970","Salary":"$275,689.9375","Address":"8 Glenn Way #3","Suburb":"Brockman","State":"WA","Post":6701,"Phone":813992471,"Mobile":490947955,"Email":"gerry_mohrmann@mohrmann.net.au","FullName":"Gerry Mohrmann","SalaryBucket":"C","age":54.0},{"Company":"Jordan, Mark D Esq","BirthDate":"20\/05\/1970","Salary":"$758,762.8750","Address":"8 W Virginia St","Suburb":"Amphitheatre","State" ...

# %%
# %sql
select * from member_data
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Company</th><th>BirthDate</th><th>Salary</th><th>Address</th><th>Suburb</th><th>State</th><th>Post</th><th>Phone</th><th>Mobile</th><th>Email</th><th>FullName</th><th>SalaryBucket</th><th>age</th></tr></thead><tbody><tr><td>Brandt, Jonathan F Esq</td><td>05/07/1970</td><td>$330,949.2188</td><td>171 E 24th St</td><td>Leith</td><td>TAS</td><td>7315</td><td>381749123</td><td>458665290</td><td>rebbecca.didio@didio.com.au</td><td>Rebbecca Didio</td><td>C</td><td>54</td></tr><tr><td>Landrum Temporary Services</td><td>17/07/1970</td><td>$309,558.5312</td><td>22222 Acoma St</td><td>Proston</td><td>QLD</td><td>4613</td><td>799973366</td><td>497622620</td><td>stevie.hallo@hotmail.com</td><td>Stevie Hallo</td><td>C</td><td>54</td></tr><tr><td>Inabinet, Macre Esq</td><td>24/01/1970</td><td>$539,508.3750</td><td>534 Schoenborn St #51</td><td>Hamel</td><td>WA</td><td>6215</td><td>855589019</td><td>427885282</td><td>mariko_stayer@hotmail.com</td><td>Mariko Stayer</td><td>C</td><td>54</td></tr><tr><td>Morris Downing & Sherred</td><td>12/06/1970</td><td>$293,515.5000</td><td>69206 Jackson Ave</td><td>Talmalmo</td><td>NSW</td><td>2640</td><td>260444682</td><td>443795912</td><td>gerardo_woodka@hotmail.com</td><td>Gerardo Woodka</td><td>C</td><td>